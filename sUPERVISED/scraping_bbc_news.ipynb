# %% [markdown]
# My code is messy and unprofessional, but i am learning it. Pushing my limits of understanding. Try to add new features and try to get the work done. Real world data collection is done like this. Nested elements, dynamic classes and all.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import urljoin

BASE_URL = "https://www.bbc.com"

# %%
session = requests.session()
response = session.get(BASE_URL)
soup = BeautifulSoup(response.text, "html.parser")

# %%
# <div data-testid="dundee-article" class="sc-f61c18b2-1 kQxjBX"><div data-testid="card-image-wrapper" class="sc-f61c18b2-3 degLZY"><div data-testid="card-media" class="sc-f61c18b2-4 glHScE"><div class="sc-5340b511-1 cMIbKV"><img sizes="25vw" srcset="https://ichef.bbci.co.uk/news/240/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 240w,https://ichef.bbci.co.uk/news/320/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 320w,https://ichef.bbci.co.uk/news/480/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 480w,https://ichef.bbci.co.uk/news/640/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 640w,https://ichef.bbci.co.uk/news/800/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 800w,https://ichef.bbci.co.uk/news/1024/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 1024w,https://ichef.bbci.co.uk/news/1536/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 1536w" src="https://ichef.bbci.co.uk/news/480/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp" loading="eager" alt="Royal Marines of M Company of 42 Commando in military fatigues and wielding guns during an operation to clear compounds used by the Taliban in Helmand Province of Southern Afghanistan" class="sc-5340b511-0 hLdNfA"></div></div></div><div data-testid="card-text-wrapper" class="sc-666b6d83-0 biYacy"><div class="sc-feaf8701-1 dzYnRP"><div class="sc-feaf8701-0 ktNWyK"><h2 data-testid="card-headline" class="sc-feaf8701-3 eQumHa">Frank Gardner: Not only Americans risked life and limb to serve in Afghanistan</h2></div></div><p data-testid="card-description" class="sc-f61c18b2-0 jktPA-D">Brits, Canadians and Danes were among those who saw the toughest fighting, writes the BBC's security correspondent.</p><div class="sc-1907e52a-0 jkvOKk"><span data-testid="card-metadata-lastupdated" class="sc-1907e52a-1 bZuSaP">10 hrs ago</span><div data-testid="card-metadata-separator" class="sc-1907e52a-3 hCbeEG"></div><span data-testid="card-metadata-tag" class="sc-1907e52a-2 dIrLFx">Asia</span></div></div></div>

# %%
output = soup.find_all("div", class_="sc-f61c18b2-1 kQxjBX")
# class = "sc-f61c18b2-1 "
output[0].get_text()
# Out:
# "Frank Gardner: Not only Americans risked life and limb to serve in AfghanistanBrits, Canadians and Danes were among those who saw the toughest fighting, writes the BBC's security correspondent.11 hrs agoAsia"

# %%
heading = output[3].find("h2", class_="sc-feaf8701-3 eQumHa").get_text(strip=True) 
heading
# Out:
# "Four attacks in 48 hours: How east Australia's beaches became a 'perfect storm' for sharks"

# %%
short_desc = output[3].find("p",class_="sc-f61c18b2-0 jktPA-D").get_text(strip=True)
short_desc
# Out:
# "Human-shark encounters in Australia are rising - but experts are keen to point out it isn't the animals' fault."

# %%
# <a href="/news/articles/cj3v2mlvzdvo" data-testid="internal-link" class="sc-8a623a54-0 huZCWi"><div data-testid="dundee-article" class="sc-f61c18b2-1 kQxjBX"><div data-testid="card-image-wrapper" class="sc-f61c18b2-3 degLZY"><div data-testid="card-media" class="sc-f61c18b2-4 glHScE"><div class="sc-5340b511-1 cMIbKV"><img sizes="25vw" srcset="https://ichef.bbci.co.uk/news/240/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 240w,https://ichef.bbci.co.uk/news/320/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 320w,https://ichef.bbci.co.uk/news/480/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 480w,https://ichef.bbci.co.uk/news/640/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 640w,https://ichef.bbci.co.uk/news/800/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 800w,https://ichef.bbci.co.uk/news/1024/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 1024w,https://ichef.bbci.co.uk/news/1536/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp 1536w" src="https://ichef.bbci.co.uk/news/480/cpsprodpb/623c/live/324e36c0-f889-11f0-b385-5f48925de19a.jpg.webp" loading="eager" alt="Royal Marines of M Company of 42 Commando in military fatigues and wielding guns during an operation to clear compounds used by the Taliban in Helmand Province of Southern Afghanistan" class="sc-5340b511-0 hLdNfA"></div></div></div><div data-testid="card-text-wrapper" class="sc-666b6d83-0 biYacy"><div class="sc-feaf8701-1 dzYnRP"><div class="sc-feaf8701-0 ktNWyK"><h2 data-testid="card-headline" class="sc-feaf8701-3 eQumHa">Frank Gardner: Not only Americans risked life and limb to serve in Afghanistan</h2></div></div><p data-testid="card-description" class="sc-f61c18b2-0 jktPA-D">Brits, Canadians and Danes were among those who saw the toughest fighting, writes the BBC's security correspondent.</p><div class="sc-1907e52a-0 jkvOKk"><span data-testid="card-metadata-lastupdated" class="sc-1907e52a-1 bZuSaP">11 hrs ago</span><div data-testid="card-metadata-separator" class="sc-1907e52a-3 hCbeEG"></div><span data-testid="card-metadata-tag" class="sc-1907e52a-2 dIrLFx">Asia</span></div></div></div></a>

full_desc_url = output[0].find("a",class_="sc-8a623a54-0 huZCWi")
full_desc_url
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
# ...

# %%
# actual logic for longterm

cards = soup.select('div[data-testid="dundee-cards"]')

# %%
for i, card in enumerate(cards):
    if i > 0:
        break
    a_tag = card.find_parent("a")
    print(a_tag["href"])
    i+=1
# Out:
# /news/articles/clym2l7d75eo

# %%
a_taga_tag["href"]
# Out:
# '/news/articles/c20zzq8we8wo'

# %%
X = requests.get(BASE_URL+a_tag["href"])
y = BeautifulSoup(X.text, "html.parser")
Contents = y.find_all("article")

for content in Contents:
    headline = y.select('[data-component="headline-block"]')
    # title = headline.get_text()
    print(headline)
# Out:
# [<div class="sc-3b6b161a-0 hNbOGD" data-component="headline-block"><h1 class="sc-f98b1ad2-0 idLnWK">Harry says sacrifices by Nato troops in Afghanistan deserve 'respect' </h1></div>]

# %%
title

# %%
HEADLINE = []
SHORT_DESC = []
REPORTER = []
NEWS = []

# %%
cards = soup.select('div[data-testid="dundee-article"]')
news_set = ""
for card in cards:
    a_tag = card.find_parent("a")
    url = urljoin("https://www.bbc.com", a_tag["href"])

    headline = card.select_one('[data-testid="card-headline"]')
    s_desc = card.select_one('[data-testid="card-description"]')

    response = session.get(url)
    deepSoup = BeautifulSoup(response.text, "html.parse")

    desc_card = deepSoup.select("article")
    reporter_span = desc_card.select('span[data-testid="byline-contributors"]')
    news = deepSoup.select('div[data-component="text-block"]')
    for n in news:
        news_set += news.get_all("p").get_text()



    # print({
    #     "title": headline.get_text(strip=True) if headline else None,
    #     "description": desc.get_text(strip=True) if desc else None,
    #     "url": url
    # })
    # print("\n")
# Out:
# {'title': "Harry says sacrifices by Nato troops in Afghanistan deserve 'respect'", 'description': "The US president's comments have been condemned by international allies, including UK veterans and politicians.", 'url': 'https://www.bbc.com/news/articles/clym2l7d75eo'}
#
#
# {'title': "India and EU set for 'mother of all deals' as Trump's tariff uncertainty looms", 'description': 'Trade negotiations are nearing the finish line after nearly two decades of hard bargaining on both sides.', 'url': 'https://www.bbc.com/news/articles/ckgyz1ejw9no'}
#
#
# {'title': 'Boy, 12, dies from injuries after Sydney shark attack', 'description': 'Nico Antic was swimming in Sydney Harbour when he was attacked last Sunday.', 'url': 'https://www.bbc.com/news/articles/c2k98ql703no'}
#
#
# ...
