# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'd:\\Job_Ready_Skills\\aI_mL\\cLASSICALmL\\sUPERVISED\\ml_project_01_classification\\notebooks'

# %%
BASE = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
PATH = os.path.join(BASE,"data","train.csv")
PATH
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 BASE = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#       2 PATH = os.path.join(BASE,"data","train.csv")
#       3 PATH
#
# NameError: name '__file__' is not defined

# %%
df = pd.read_csv(DATA_PATH)
df.head()
